# %%
import os
import glob
import pandas as pd
import numpy as np
import re
import unicodedata

# %%
def clean_text(text):
    return re.sub(r'[^a-zA-Z0-9.%/,-]', '', text)

def normalize_text(text):
    """Remove hidden Unicode control characters like \u202d"""
    return unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('ascii')

def is_numeric(s):
    return s.apply(lambda x: re.fullmatch(r'\d+', x) is not None).all()

def is_decimal(s):
    return s.apply(lambda x: re.fullmatch(r'\d+\.\d+', x) is not None).all()

def has_special_characters(s):
    return s.apply(lambda x: any(c in x for c in ['/', '-', ',', '.', '%'])).any()

def is_alphanumeric(s):
    return s.apply(lambda x: re.fullmatch(r'[A-Za-z0-9]+', x) is not None).all()

def is_mostly_letters(s, threshold=1.0):
    letter_counts = s.apply(lambda x: sum(c.isalpha() for c in x))
    total_counts = s.apply(lambda x: len(x))
    ratios = letter_counts / total_counts
    return (ratios == threshold).mean() >= 1.0

def fixed_length(s):
    cleaned = s.apply(clean_text)
    lengths = cleaned.apply(len).unique()
    return len(lengths) == 1

# %%
def load_input_file(input_directory):
    files = glob.glob(os.path.join(input_directory, "*.xlsx"))
    if not files:
        raise FileNotFoundError("No XLSX file found.")
    file_path = files[0]
    df = pd.read_excel(file_path, skiprows=0)
    df_for_mapping = df.head(10)
    print(f"Loaded input file '{file_path}' with {len(df)} rows. Using top 10 rows for mapping.")
    return df, df_for_mapping

# %%
def load_seed_files(seed_directory):
    seed_files = glob.glob(os.path.join(seed_directory, "*.csv"))
    seeds = {}
    for file in seed_files:
        df = pd.read_csv(file, skipinitialspace=True, dtype=str)
        df.columns = df.columns.str.strip()   
        filename = os.path.splitext(os.path.basename(file))[0]
        seeds[filename] = df
        print(f"Loaded seed file: '{filename}' with {len(df)} rows.")
    return seeds

# %%
def find_primary_keys(df, tolerance=0):
    primary_keys = []
    for col in df.columns:
        s = df[col].dropna().astype(str).apply(normalize_text).apply(clean_text)
        if s.empty:
            continue
        total_count = len(s)
        unique_count = len(s.unique())
        
        if total_count - unique_count <= tolerance:
            primary_keys.append(col)
            # print(f"Primary key candidate: '{col}' (Total: {total_count}, Unique: {unique_count})")
        else:
            #  Debug print if duplicates found
            # print(f"\nColumn '{col}' not picked as primary key (Total: {total_count}, Unique: {unique_count}).")
            # print(f"Finding duplicates for '{col}'...\n")
            duplicated_values = s[s.duplicated(keep=False)]
            if not duplicated_values.empty:
                print(df.loc[duplicated_values.index, [col]])
            print("-" * 50)

    return primary_keys

# %%
def analyze_column_properties(s):
    cleaned_s = s.dropna().astype(str).apply(normalize_text).apply(clean_text)
    properties = {
        'is_numeric': is_numeric(cleaned_s),
        'is_decimal': is_decimal(cleaned_s),
        'has_special_characters': has_special_characters(cleaned_s),
        'is_alphanumeric': is_alphanumeric(cleaned_s),
        'is_mostly_letters': is_mostly_letters(cleaned_s),
        'is_fixed_length': fixed_length(cleaned_s),
        'length': cleaned_s.apply(len).unique()[0] if fixed_length(cleaned_s) else None
    }
    return properties

# %%
def map_columns(input_sample, seed_col_name, seed_col_values, seed_props):
    matches = []
    for col in input_sample.columns:
        s_input = input_sample[col].dropna().astype(str).apply(normalize_text).apply(clean_text)
        if s_input.empty:
            continue
        cleaned_input = s_input

        input_props = {
            'is_numeric': is_numeric(cleaned_input),
            'is_decimal': is_decimal(cleaned_input),
            'has_special_characters': has_special_characters(cleaned_input),
            'is_alphanumeric': is_alphanumeric(cleaned_input),
            'is_mostly_letters': is_mostly_letters(cleaned_input),
            'is_fixed_length': fixed_length(cleaned_input),
            'length': cleaned_input.apply(len).unique()[0] if fixed_length(cleaned_input) else None
        }

        conditions = all(seed_props[key] == input_props.get(key) for key in seed_props)
        # conditions = all(
        #     seed_props[key] == input_props.get(key)
        #     or (key in ['has_special_characters', 'is_mostly_letters'] and True)
        #     for key in seed_props
        # )

        if conditions:
            print(f"Matched input column '{col}' for seed column '{seed_col_name}'")
            matches.append(col)
    
    if not matches:
        print(f"No match found for seed column '{seed_col_name}'")
    
    return matches

# %%
# Step 8: Full processing flow

input_directory = "input"
seed_directory = "seeds"

# Load input file
full_input_df, input_sample = load_input_file(input_directory)

# Load seed files
seeds = load_seed_files(seed_directory)

# Analyze and map
all_mappings = {}

for seed_name, seed_df in seeds.items():
    print(f"\n=== Processing seed file '{seed_name}' ===")
    primary_keys = find_primary_keys(seed_df)

    mappings = []
    for pk_col in primary_keys:
        if pk_col not in seed_df.columns:
            continue

        seed_col_values = seed_df[pk_col]
        seed_props = analyze_column_properties(seed_col_values)

        print(f"\nProperties for seed column '{pk_col}': {seed_props}")
        
        matched_cols = map_columns(input_sample, pk_col, seed_col_values, seed_props)

        if matched_cols:
            mappings.append({
                'seed_column': pk_col,
                'matched_input_columns': matched_cols,
                'seed_properties': seed_props
            })

    all_mappings[seed_name] = mappings
# Out:
# Loaded input file 'input/main_input.xlsx' with 1669 rows. Using top 10 rows for mapping.
# Loaded seed file: 'druva_seed' with 644 rows.
#
# === Processing seed file 'druva_seed' ===
#            GSTIN/UID
# 319  27AAAFW4298E1ZY
# 320  27ADBFS5581J1ZO
# 321  29ABOFS7511F1ZU
# 322  27AAQFV2256H1ZR
# 323  27AAXFR4592D1ZL
# 324  27ADEFS7931B1Z4
# 325  27ADMFS4228H1ZS
# 326  27AAXFP4248E1ZS
# 327  27AAEFP1428R1ZS
# 328  27AAAFK1415H1ZR
# 329  27AAFFL1052J1ZF
# 330  27ABIFM0007A1ZZ
# 331  27AALFK8338E1Z2
# 332  27AATFK2284M1ZK
# 333  27AAOFK0606N1Z1
# 334  24AAPFD2680Q1ZT
# 335  27AACFD4815A2ZZ
# 336  27AACFG9740K1Z2
# 337  24CIKPS6663M1ZG
# 348  24CIKPS6663M1ZG
# 371  27ADBFS5581J1ZO
# 411  27AAEFP1428R1ZS
# 442  29ABOFS7511F1ZU
# 484  27ADMFS4228H1ZS
# 486  27ADEFS7931B1Z4
# 490  27ABIFM0007A1ZZ
# 498  27AAXFR4592D1ZL
# 499  27AAXFP4248E1ZS
# 505  27AATFK2284M1ZK
# 509  27AAQFV2256H1ZR
# 512  27AAOFK0606N1Z1
# 517  27AALFK8338E1Z2
# 530  27AAFFL1052J1ZF
# 549  27AACFG9740K1Z2
# 550  27AACFD4815A2ZZ
# 584  27AAAFW4298E1ZY
# 586  27AAAFK1415H1ZR
# 613  24AAPFD2680Q1ZT
# 626  07AAACJ0054A1ZD
# 627  07AAACJ0054A1ZD
# --------------------------------------------------
#     State/Province Display Name
# 0                   Maharashtra
# 1                     Karnataka
# 2                   Maharashtra
# 4                   Maharashtra
# 5                   Maharashtra
# ..                          ...
# 631               Uttar Pradesh
# 632                     Haryana
# 633                     Gujarat
# 634                 Maharashtra
# 635                 Maharashtra
#
# [579 rows x 1 columns]
# --------------------------------------------------
#
# Properties for seed column 'S_no': {'is_numeric': True, 'is_decimal': False, 'has_special_characters': False, 'is_alphanumeric': True, 'is_mostly_letters': False, 'is_fixed_length': False, 'length': None}
# Matched input column 'Document Number' for seed column 'S_no'
#
# Properties for seed column 'Name': {'is_numeric': False, 'is_decimal': False, 'has_special_characters': True, 'is_alphanumeric': False, 'is_mostly_letters': False, 'is_fixed_length': False, 'length': None}
# Matched input column 'Vendor' for seed column 'Name'
# Matched input column 'Item' for seed column 'Name'
# Matched input column 'Account' for seed column 'Name'
# Matched input column 'Memo' for seed column 'Name'
# Matched input column 'Amount (Trxn Currency) w/ Correct GL Sign' for seed column 'Name'
# Matched input column 'Amount (Base Currency) w/ Correct GL Sign' for seed column 'Name'

# %%
print("\n=== Final Mapping Results ===")
for seed_name, mappings in all_mappings.items():
    for mapping in mappings:
        input_cols = ", ".join(mapping['matched_input_columns'])
        print(f"Seed File '{seed_name}': '{mapping['seed_column']}' -> {input_cols}")
# Out:
# === Final Mapping Results ===
# Seed File 'druva_seed': 'S_no' -> Document Number
# Seed File 'druva_seed': 'Name' -> Vendor, Item, Account, Memo, Amount (Trxn Currency) w/ Correct GL Sign, Amount (Base Currency) w/ Correct GL Sign

# %%
final_verified_mappings = {}

for seed_name, mappings in all_mappings.items():
    final_verified_mappings[seed_name] = []
    for mapping in mappings:
        seed_column_name = mapping['seed_column']
        full_seed_col_values = seeds[seed_name][seed_column_name].dropna().astype(str).apply(lambda x: x.strip())

        for input_col_name in mapping['matched_input_columns']:
            if input_col_name not in full_input_df.columns:
                continue
            full_input_col_values = full_input_df[input_col_name].dropna().astype(str).apply(lambda x: normalize_text(x.strip()))


            input_unique = set(full_input_col_values)
            seed_unique = set(full_seed_col_values)

            if not input_unique:
                continue

            common_elements = input_unique & seed_unique
            ratio = len(common_elements) / len(input_unique)

            print(f"\nMapping Attempt: '{seed_name}:{seed_column_name}' -> '{input_col_name}'")
            print(f"Input Unique Values ({input_col_name}): {sorted(input_unique)}")
            print(f"Seed Unique Values ({seed_column_name}): {sorted(seed_unique)}")
            print(f"Common Values: {sorted(common_elements)}")
            print(f"Input Unique Count: {len(input_unique)}, Common Count: {len(common_elements)}, Ratio: {ratio:.2f}")

            if ratio >= 0.8:
                print(" Mapping Accepted based on Common Elements Ratio.\n")
                final_verified_mappings[seed_name].append({
                    'seed_column': seed_column_name,
                    'input_column': input_col_name,
                    'ratio': ratio
                })
            else:
                print("Mapping Rejected based on Common Elements Ratio.\n")

print("\n=== Final Verified Mappings ===")
for seed_name, verified_list in final_verified_mappings.items():
    for verified in verified_list:
        print(f"Seed File '{seed_name}': Seed Column '{verified['seed_column']}' -> Input Column '{verified['input_column']}' (Ratio: {verified['ratio']:.2f})")
# Out:
# Mapping Attempt: 'druva_seed:S_no' -> 'Document Number'
# Input Unique Values (Document Number): ['000002568431040', '000002568431046', '000002568431047', '000002568431052', '001/2024-25', '002425-000386', '002425-000387', '002425-000388', '002425-000390', '002425-000391', '002425-000392', '002425-000393', '002425-000394', '002425-000395', '002425-000396', '002425-000397', '002425-000398', '002425-000399', '002425-000400', '002425-000401', '002425-000402', '002425-000403', '002425-000404', '002425-000405', '002425-000406', '002425-000407', '002425-000408', '002425-000409', '002425-000410', '002425-000411', '002425-000412', '002425-000413', '002425-000414', '002425-000415', '009/24-25', '016471510232114', '019', '085-2425', '100/24-25', '100424281612', '100624886644', '1007242631962', '1007242632281', '1007242632455', '1007243304659', '1008241043731', '1008243004813', '1009241967354', '1009242326077', '1009243072542', '102/24-25', '115', '151118137', '154', '155', '185', '186', '18958', '19226058502', '2024-2025/1606', '2024-2025/1608', '2024-2025/1609', '2024-2025/1610', '2024-2025/1611', '2024-2025/1612', '2024-25/259', '2024-25/S/419', '2024-25/S/422', '20240727I11764', '202407591', '202407783', '21', '217/EA/2024-2025', '2170505595', '2170576886', '23444', '24', '24-25/SBD/PF/109', '24/15045', '2408/74', '2409/79', '2410718003', '2425-LLP-1085', '2425-LLP-1090', '2425-LLP-1166', '242546533', '242546534', '242546589', '245', '246', '25', '2556', '29', '358/24-25/106', '358/24-25/305', '358/24-25/406', '358/24-25/505', '3926-321313', '3926-321343', '500010186350', '6', '6100328259', '795A94', '88', 'AL/36/25/0000106', 'Advance - Sep 24- Peraverde Ventures', 'Advance reversed', 'Advance-Aug 24-Delhi Kitchen', 'Advance-Aug 24-Prathamesh Resort', 'Advance-Sep 23-Maia Hospitality', 'Advance-Sep 24-Vishwas Villa Resort', 'C3K3PCHZB4005U21', 'C3K3PCHZB4005V21', 'CTQ24250092', 'D202413', 'D2413-107', 'DOM/FY2024-25/21', 'DP416385', 'DP416386', 'DP416646', 'DP416647', 'DP416648', 'DP416649', 'DP418332', 'DP418333', 'DP418340', 'DP418342', 'DP418786', 'DP418787', 'DP418788', 'DP418789', "DhanshriBDeoreSept'24", 'E0700TOYMZ', 'Ext.131', 'F-7574', 'FEPL2425069', 'FM3098BIL0005675', 'FM3098BIL0005764', 'FM3098BIL0005787', 'FM3098BIL0005912', 'FM3098BIL0006109', 'FM3098BIL0006417', 'FM3098BIL0006570', 'FPNB-40675', 'GGS-09242077772', 'GGS-09242077774', 'HB/MH/24-25/0791', 'HR/2024-25/020', 'HYD3-503124', 'HYD8-1756118', 'HYD8-28128', 'Hyd/001', 'ICICI Credit Card Sep 24 Statement INR', 'ICICI Credit
VATE  LIMITED (Hunger Box)', 'EN-50-EQ TECHNOLOGIC (INDIA) PRIVATE LIMITED', 'EN-50-EXPRESS MARKETING', 'EN-50-Fidato Events Private Ltd', 'EN-50-GitHub INC', 'EN-50-ICICI Credit Card', 'EN-50-ICICI LOMBARD GENERAL INSURANCE CO. LTD', 'EN-50-ICICI LOMBARD GENERAL INSURANCE CO. LTD - Travel Insurance', 'EN-50-ILife IT Solutions Pvt Ltd', 'EN-50-ITC-MARATHA', 'EN-50-Jetways Travels Pvt Ltd', 'EN-50-KANJ & CO. LLP', 'EN-50-KPMG', 'EN-50-Khushi Caterers', 'EN-50-LEGALOGIC CONSULTING LLP', 'EN-50-LINK SUCCESS', 'EN-50-MICROGENESIS TECHSOFT PRIVATE LIMITED', 'EN-50-MIGHTY GOOD HOSPITALITY', 'EN-50-MSEDCL', 'EN-50-Maheshwari Foods & Hospitality (Pune) LLP', 'EN-50-Matrix Cellular International Services Pvt Ltd', 'EN-50-Microsoft Corporation (India) Pvt. Ltd', 'EN-50-Nikhil Sunil Pathak', 'EN-50-Omkar Enterprises', 'EN-50-Online Instruments(India) Pvt Ltd', 'EN-50-PALANDE ELECTRICALS', 'EN-50-PARVEEN FLEETS PRIVATE LIMITED', 'EN-50-PGH EXPRESS KITCHEN LLP', 'EN-50-PRATHAMESH RESORTS', 'EN-50-Padcare Labs Private Limited', 'EN-50-Pankaj R Pipada', 'EN-50-Perfect Solution', 'EN-50-Price Waterhouse Coopers LLP', 'EN-50-QUALITY HOUSE KEEPING MATERIAL SUPPLIERS', 'EN-50-RADIUS SYSTEMS PRIVATE LIMITED', 'EN-50-RAINMAKER ONLINE TRAINING SOLUTIONS PRIVATE LIMITED', 'EN-50-ROOTS OFFICE SOLUTIONS', 'EN-50-RVKLS  Hospitality And Mgmt  LLP', 'EN-50-Radha  Shelat', 'EN-50-Ramee Hotel Pvt Ltd', 'EN-50-ResilienceWorks Consultation services Pvt Ltd', 'EN-50-SAFE AIR ENGINEERS PRIVATE LIMITED', 'EN-50-SMARTTECH SECURE SOLUTION PRIVATE LIMITED', 'EN-50-STRATEGIC INTELLECTUAL PROPERTY SOLUTIONS', 'EN-50-STYPRO OFFICE AND HYGIENE SOLUTIONS PVT LTD', 'EN-50-SUJATA COMPUTERS PVT LTD', 'EN-50-Sai Concierge Services', 'EN-50-Samyak Restaurant LLP', 'EN-50-SpryIQ Technologies Private Limited', 'EN-50-TATA TELESERVICES LTD', 'EN-50-Uber India Sytems Private Limited', 'EN-50-Unique Solutions', 'EN-50-VG  CLOUD', 'EN-50-VISHWAS VILLA RESORT', 'EN-50-VISHWIJA FOODS LLP', 'EN-50-Vasu Enterprises', 'EN-50-WADESHWAR RESTAURANTS PRIVATE LIMITED', 'EN-50-WENGER & WATSON BUSINESS SYSTEMS PRIVATE LIMITED', 'EN-50-Walker Chandiok & Co LLP']
# Input Unique Count: 89, Common Count: 79, Ratio: 0.89
#  Mapping Accepted based on Common Elements Ratio.
#
#
# Mapping Attempt: 'druva_seed:Name' -> 'Item'
# Input Unique Values (Item): ['AMC', 'Airfare', 'Asset  Computer Equipment', 'Asset Office Equipment', 'Awards', 'Cab Services', 'Charitable Contribution-CSR', 'Computer Accessories', 'Contractor - India', 'Credit Card Clearing-GST Expense', 'Credit Card Expense', 'Diesel Charges', 'Electrical Material', 'Electricity Charges', 'Employee  Goodies', 'Field Events', 'GST @12% Group', 'GST @18% Group', 'GST @28% Group', 'GST @5% Group', 'GST_RCM @100% of @18% Group', 'Housekeeping Items', 'Housekeeping Staff', 'IGST @12% Group', 'IGST @18% Group', 'IGST @5% Group', 'IGST_RCM @100% of @18 % Group', 'Insurance Charges', 'Internet Office', 'Internship Payment', 'Lodging', 'Office Maintenance', 'Office Supplies', 'Pantry Items', 'Parking charges (Two & Four Wheeler)', 'Professional Fees', 'Professional Fees - RCM', 'Recruitment Fees', 'Rent Delhi Office', 'Rent Pune Office', 'Security Staff', 'Stationary', 'Subscription Software', 'Subscription Software-RCM', 'TDS on 194Q', 'TDS on Contractors', 'TDS on Professional Service', 'TDS on Rent', 'Team Outing Events', 'Training Expenses', 'VISA Fee Charges', 'ZERO Group']
# Seed Unique Values (Name): ['!DNU_200727_EN-50-Amazon', '!DNU_200727_EN-50-Datavizz', '!DNU_200727_EN-50-Deloitte Haskins Sells LLP', '!DNU_200727_EN-50-GRANT THORNTON INDIA LLP', '!DNU_200727_EN-50-KAMDHENU XEROX & STATIONERY', '!DNU_200727_EN-50-KANJ & CO. LLP', '!DNU_200727_EN-50-KPMG', '!DNU_200727_EN-50-Khushi Caterers', '!DNU_200727_EN-50-Legalogic Consulting', '!DNU_200727_EN-50-Maheshwari Foods & Hospitality (Pune) LLP', '!DNU_200727_EN-50-PGH EXPRESS KITCHEN LLP', '!DNU_200727_EN-50-Price Waterhouse Coopers LLP', '!DNU_200727_EN-50-RJ 12 TEA AND COFFEE SHOP', '!DNU_200727_EN-50-SAARVAM & ASSOCIATES', '!DNU_200727_EN-50-SAC & Co LLP', '!DNU_200727_EN-50-SHUBAN INTERNATIONAL', '!DNU_200727_EN-50-STRATEGIC INTELLECTUAL PROPERTY SOLUTIONS', '!DNU_200727_EN-50-Vipanan Analytical Technologies LLP', '!DNU_200727_EN-50-Walker Chandiok & Co LLP', 'Default Tax Agency IN', 'EN-50- Akshata   Baniya', 'EN-50- Ganesh    Pore', 'EN-50-121 Connects Private Limited', 'EN-50-9.9 GROUP PRIVATE LIMITED', 'EN-50-A2Z ONLINE SERVICES PVT LTD', 'EN-50-AARA VILLA', 'EN-50-AAYATI ECOVENTURES PRIVATE LIMITED', 'EN-50-AAYUSHI RAVI NARAYAN', 'EN-50-ABHINANDAN  SINGH', 'EN-50-ABP PVT LTD', 'EN-50-ACE DATA DEVICES PVT LTD', 'EN-50-ADFACTORS PR PRIVATE LIMITED', 'EN-50-ADITYA BIRLA HEALTH SERVICES PRIVATE LIMITED', 'EN-50-ADP INDIA PRIVATE LIMITED', 'EN-50-AFour Technologies Pvt.Ltd.', 'EN-50-AGARWAL HOSPITALITY PRIVATE LIMITED', 'EN-50-AJANTA TECHAGRO LAND DEVELOPMENT PRIVATE LTD', 'EN-50-AJIT ELECTRICALS', 'EN-50-ALIKE THOUGHTS SOLUTIONS', 'EN-50-ALLIED SERVICES', 'EN-50-ALLSEC TECHNOLOGIES LIMITED', 'EN-50-AMBIENCE HOTELS & RESORTS PRIVATE LIMITED', 'EN-50-AMIT DILIP SHINDORE', 'EN-50-AMPLE DIGITAL PRIVATE LIMITED', 'EN-50-AMPLE TECHNOLOGIES PRIVATE LIMITED', 'EN-50-AMRUT SOFTWARE PRIVATE LIMITED', 'EN-50-AMRUTA S ZENDE', 'EN-50-ANI  TECHNOL OGIES  PRIVATE  LIMITED (Ola Cabs)', 'EN-50-ANICHE INFOTECH SOLUTIONS PRIVATE LIMITED', 'EN-50-ANSEC HUMAN RESOURCE SERVICES LIMITED', 'EN-50-ANZY CAREERS PRIVATE LIMITED', 'EN-50-ARA RESOURCES PRIVATE LIMITED', 'EN-50-ARANYAGIRI COUNTRYSIDE RESORT', 'EN-50-ARYAN ENTERPRISES_Ajit Sharma', 'EN-50-ASTRA SYSTEMS', 'EN-50-ATLASSIAN Pty Ltd (Jira)', 'EN-50-AWFIS SPACE SOLUTIONS PRIVATE LIMITED', 'EN-50-AWLIV LIVING SOLUTIONS PRIVATE LIMITED', 'EN-50-AZURE RESTAURANTS PUNE PVT LTD', 'EN-50-Aayush H Shah', 'EN-50-Abhay  S Wagh', 'EN-50-Abhay K Shirale', 'EN-50-Abhishek P  More', 'EN-50-Accutech Power Solution Pvt Ltd', 'EN-50-Aditya  R Manapure', 'EN-50-Aditya S Vaidya', 'EN-50-Adorit IT Services Pvt Ltd', 'EN-50-Advait M  Thakur', 'EN-50-Adventure Mantra Pvt Ltd', 'EN-50-Aegon Life Insurance Company Limited', 'EN-50-Akash Mishra', 'EN-50-Alliance Pro IT Pvt Ltd', 'EN-50-Amazon', 'EN-50-American Express INR (Amex) ( Card No 3765 35363731002', 'EN-50-Amisha M Pawar', 'EN-50-Amit Enterprises', 'EN-50-Amruta Patwardhan', 'EN-50-Anantta Hospitality', 'EN-50-Aniket S Kankekar', 'EN-50-Anjali Babasaheb Gaikwad', 'EN-50-Anvay Enterprises', 'EN-50-Aon Consulting, Inc. (NJ)', 'EN-50-Apple South Asia Pte Ltd', 'EN-50-Apurva A Khamkar', 'EN-50-Asawari  S Sayagaon', 'EN-50-Ashapura Agency', 'EN-50-Ashish Deepak Karkare', 'EN-50-Asma Tamboli', 'EN-50-Aspose Pty Ltd', 'EN-50-Assure Hrlabs India Pvt Ltd', 'EN-50-BALAJI STATIONERY & SUPPLIER', 'EN-50-BAMBOO AND BRICKS RESORT', 'EN-50-BC EDUCATION INDIA PRIVATE LIMITED', 'EN-50-BENIR E STORE SOLUTION', 'EN-50-BENISON TECHNOLOGIES PRIVATE LIMITED', 'EN-50-BENNETT COLEMAN & CO LTD', 'EN-50-BHANDARMATH MEDIA WORKS (RJ Prabhu)', 'EN-50-BITS PILANI K K BIRLA GOA CHAMPUS', 'EN-50-BLOB INFOTECH PRIVATE LIMITED', 'EN-50-BOUGAINVILLEA RESORT', 'EN-50-BOX Inc', 'EN-50-BRAHMADNYA FOODS', 'EN-50-BRAMHACORP LIMITED', 'EN-50-BRIO TECHNOLOGIES PRIVATE LIMITED', 'EN-50-BROWSERSTACK.COM', 'EN-50-Balaji  Janakiraman', 'EN-50-Bharti Airtel Ltd', 'EN-50-Bhavik  G Ransubhe', 'EN-50-Bistro Hospitality Pvt Ltd', 'EN-50-Blue Leaf Corporate Solutions P Ltd', 'EN-50-Bluebell Telesystem and Services', 'EN-50- ...
# Common Values: []
# Input Unique Count: 52, Common Count: 0, Ratio: 0.00
# Mapping Rejected based on Common Elements Ratio.
#
#
# Mapping Attempt: 'druva_seed:Name' -> 'Account'
# Input Unique Values (Account): ['13025 Prepaids : Prepaid Events', '13040 Prepaids : Prepaid Subscription & Services', '15010 Fixed Assets : Computer Equipment', '15030 Fixed Assets : Office Equipment', '22025 Accrued Expenses : Credit Card Clearing', '23012 Accrued Taxes : IGST_RCM Not paid', '23013 Accrued Taxes : CGST_RCM Not paid', '23014 Accrued Taxes : SGST_RCM Not paid', '23015 Accrued Taxes : IGST_RCM Payable', '23016 Accrued Taxes : CGST_RCM Payable', '23017 Accrued Taxes : SGST_RCM Payable', '23022 Accrued Taxes : GST Input', '23024 Accrued Taxes : SGST Input', '23025 Accrued Taxes : SGST Output', '23026 Accrued Taxes : CGST Input', '23027 Accrued Taxes : CGST Output', '23028 Accrued Taxes : IGST Input', '23029 Accrued Taxes : IGST Output', '23052 Accrued Taxes : Output - India - TDS 94J Payable', '23055 Accrued Taxes : Output - India - TDS 94I Payable', '23056 Accrued Taxes : Output - India - TDS 94C Payable', '23058 Accrued Taxes : Output - India - TDS 194Q Payable', '61505 Employee Expenses : Employee Meals & Events', '61515 Employee Expenses : Training Expenses', '61530 Employee Expenses : Employee Awards', '62010 Travel and Entertainment : Telephone-Employee', '62015 Travel and Entertainment : Airfare', '62020 Travel and Entertainment : Car Rental', '62025 Travel and Entertainment : Lodging', '62510 Outside Services : Contractors', '62520 Outside Services : Expensed Computer Hardware', '62525 Outside Services : Professional Services', '63515 Recruiting Expenses : Recruitment Expense', '64010 Software Subscription : Software Subscription', '64510 Business Fees and Taxes : Business Insurance', '65005 Facilities : Rent', '65010 Facilities : Utilities', '65015 Facilities : Repairs and Maintenance-Office', '65025 Facilities : Internet - Office', '65030 Facilities : Office Supplies', '65035 Facilities : Printing & Stationary', '65040 Facilities : Security Charges', '65055 Facilities : Housekeeping expenses', '65605 Marketing Expenses : Field Events', '66515 Other OPEX : Charitable contributions']
# Seed Unique Values (Name): ['!DNU_200727_EN-50-Amazon', '!DNU_200727_EN-50-Datavizz', '!DNU_200727_EN-50-Deloitte Haskins Sells LLP', '!DNU_200727_EN-50-GRANT THORNTON INDIA LLP', '!DNU_200727_EN-50-KAMDHENU XEROX & STATIONERY', '!DNU_200727_EN-50-KANJ & CO. LLP', '!DNU_200727_EN-50-KPMG', '!DNU_200727_EN-50-Khushi Caterers', '!DNU_200727_EN-50-Legalogic Consulting', '!DNU_200727_EN-50-Maheshwari Foods & Hospitality (Pune) LLP', '!DNU_200727_EN-50-PGH EXPRESS KITCHEN LLP', '!DNU_200727_EN-50-Price Waterhouse Coopers LLP', '!DNU_200727_EN-50-RJ 12 TEA AND COFFEE SHOP', '!DNU_200727_EN-50-SAARVAM & ASSOCIATES', '!DNU_200727_EN-50-SAC & Co LLP', '!DNU_200727_EN-50-SHUBAN INTERNATIONAL', '!DNU_200727_EN-50-STRATEGIC INTELLECTUAL PROPERTY SOLUTIONS', '!DNU_200727_EN-50-Vipanan Analytical Technologies LLP', '!DNU_200727_EN-50-Walker Chandiok & Co LLP', 'Default Tax Agency IN', 'EN-50- Akshata   Baniya', 'EN-50- Ganesh    Pore', 'EN-50-121 Connects Private Limited', 'EN-50-9.9 GROUP PRIVATE LIMITED', 'EN-50-A2Z ONLINE SERVICES PVT LTD', 'EN-50
 'EN-50-BITS PILANI K K BIRLA GOA CHAMPUS', 'EN-50-BLOB INFOTECH PRIVATE LIMITED', 'EN-50-BOUGAINVILLEA RESORT', 'EN-50-BOX Inc', 'EN-50-BRAHMADNYA FOODS', 'EN-50-BRAMHACORP LIMITED', 'EN-50-BRIO TECHNOLOGIES PRIVATE LIMITED', 'EN-50-BROWSERSTACK.COM', 'EN-50-Balaji  Janakiraman', 'EN-50-Bharti Airtel Ltd', 'EN-50-Bhavik  G Ransubhe', 'EN-50-Bistro Hospitality Pvt Ltd', 'EN-50-Blue Leaf Corporate Solutions P Ltd', 'EN-50-Bluebell Telesystem and Services', 'EN-50- ...
# Common Values: []
# Input Unique Count: 45, Common Count: 0, Ratio: 0.00
# Mapping Rejected based on Common Elements Ratio.
#
#
# Mapping Attempt: 'druva_seed:Name' -> 'Memo'
# Input Unique Values (Memo): ['11TH FLOOR-BILL OF ELECTRICAL SUPPLY FOR THE MONTH OF AUGUST 24 FOR MSEDCL', '11th Floor Common Area Maintenance Charge Month of Sept_2024.', '11th floor Rent for Sep 24 ( revised rate wef from 15th Sep 24, attached excel sheet)', '20 LTR Water bottle expense for the Month 21/07/2024. To 20/08/2024 for Vasu Enterprise', '20 LTR Water bottle expense for the Month 21/08/2024. To 20/09/2024 for Vasu Enterprise', '30W USB-C Power Adapter - MW2G3HN/A', '4 Wheeler & 2 Wheeler Monthly Parking Charges Month of Sept - 2024', '58-Piece Screwdriver Set - Precision Slotted, Phillips, Torx paid thru Dominic D ICICI Credit card', '7TH FLOOR-BILL OF ELECTRICAL SUPPLY FOR THE MONTH OF AUGUST 24 FOR MSEDCL', '7th Floor Common Area Maintenance Charges Month of Sept 2024 for A2z Online Services Pvt Ltd', '7th Floor rent for Sep-24', '8TH FLOOR-BILL OF ELECTRICAL SUPPLY FOR THE MONTH OF AUGUST 24 FOR MSEDCL', '8th & 9th Floor Common Area Maintenance Charges Month of Sept 2024 for A2z Online Services Pvt Ltd', '9TH FLOOR-BILL OF ELECTRICAL SUPPLY FOR THE MONTH OF AUGUST 24 FOR MSEDCL', 'ACCESS CARD - 13MHZ', 'Access  card required for Pune office Eligible as per Aug-2024 GSTR3B', 'Adapter', 'Additional IP Charges - AdvArr {charges10th sep 24-31st Mar 25', 'Additional IP Charges - AdvArr {charges1st Apr 25-9th Sep 25', 'Administrative surcharge', 'Advance paid for Sales - Renewals team-Q2', 'Advance payment for Enterprise Workload Q2 outing', 'Advance payment for Q2 Outing -Insync and Realize team', 'Advance reversed, working attached', 'Ahmedabad Trip for   Ashish Jain', 'Air Fare for Bengaluru Trip  Amit Gupta', 'Air Fare for Bhubaneshwar Trip  Sourav Ray', 'Air Fare for Chennai / Madras Trip  Sahil Gadroo', 'Air Fare for Chennai Trip  Ashish Jain', 'Air Fare for Chennai Trip  Kunal Agarwal', 'Air Fare for Chennai Trip  Sourav Ray', 'Air Fare for Mumbai Trip  Bakshish Dutta', 'Air Fare for Mumbai Trip  Kunal Agarwal', 'Air Fare for Mumbai Trip Kunal Agarwal', 'Air fare charges for Mr.  Mr. Prahlad Nishal  -PNQ/DEL Date of Travel 10/10/2024.', 'Air fare charges for Mr. Devendra Durgapal- BLR/PNQ Date of Travel 06/10/2024', 'Air fare charges for Mr. Devendra Durgapal- BLR/PNQ Date of Travel 22/09/2024', 'Air fare charges for Mr. Devendra Durgapal- PNQ/BLR Date of Travel 10/10/2024', 'Air fare charges for Mr. Devendra Durgapal- PNQ/BLR Date of Travel 27/09/2024', 'Air fare charges for Mr. Krishna Shekhar - BLR/PNQ Date of Travel 25/08/2024.', 'Air fare charges for Mr. Krishna Shekhar - PNQ/BLR Date of Travel 31/08/2024.', 'Air fare charges for Mr. Phanindre Baguant- PNQ/DXB Date of Travel 12/10/2024  & DXB/PNQ Date of Travel 20/10/2024', 'Air fare charges for Mr. Prahlad Nishal -DEL/PNQ Date of Travel 23/09/2024.', 'Air fare charges for Mr. Shakti Pandey - HYD/PNQ Date of Travel 22/09/2024.', 'Air fare charges for Mr. Shakti Pandey - PNQ/HYD Date of Travel 27/09/2024.', 'Air fare charges for Ms. Anuja Pawar - HYD/PNQ Date of Travel 30/08/2024.', 'Air fare charges for Ms. Anuja Pawar - PNQ/HYD Date of Travel 29/08/2024.', 'Air fare charges for Ms. Ira Merchant - HYD/PNQ Date of Travel 30/08/2024.', 'Air fare charges for Ms. Ira Merchant - PNQ/HYD Date of Travel 29/08/2024.', 'Allen Solly Cotton T - Shirt', 'Allocation Entry for Aug-2024 as per GST Return  of ISD', 'App, Dashboard access, employee feedback Feedback service in app, daily wallet, recharge services, customer support for tech issues and menu addition_x000D_\n_x000D_\nMonth of  01-August -2023 To 31-August-2024', 'Artificial Flowers Plants Purchase paid thru Dominic D ICICI Credit card', 'Bangalore Trip for   Bakshish Dutta', 'Bank Charges for ESOP Payment -March-2024  Invoice', 'Bank Charges for ESOP Payment -March-2024 Invoice', 'Bank Charges for ESOP Payment -March-2024 Invoice-Value of supply FC Conversion Tax CGST', 'Bank Charges for ESOP Payment -March-2024 Invoice-Value of supply FC Conversion Tax SGST', 'Bill no SAPUN003760/2021- time-barred ITC availe ...
# Seed Unique Values (Name): ['!DNU_200727_EN-50-Amazon', '!DNU_200727_EN-50-Datavizz', '!DNU_200727_EN-50-Deloitte Haskins Sells LLP', '!DNU_200727_EN-50-GRANT THORNTON INDIA LLP', '!DNU_200727_EN-50-KAMDHENU XEROX & STATIONERY', '!DNU_200727_EN-50-KANJ & CO. LLP', '!DNU_200727_EN-50-KPMG', '!DNU_200727_EN-50-Khushi Caterers', '!DNU_200727_EN-50-Legalogic Consulting', '!DNU_200727_EN-50-Maheshwari Foods & Hospitality (Pune) LLP', '!DNU_200727_EN-50-PGH EXPRESS KITCHEN LLP', '!DNU_200727_EN-50-Price Waterhouse Coopers LLP', '!DNU_200727_EN-50-RJ 12 TEA AND COFFEE SHOP', '!DNU_200727_EN-50-SAARVAM & ASSOCIATES', '!DNU_200727_EN-50-SAC & Co LLP', '!DNU_200727_EN-50-SHUBAN INTERNATIONAL', '!DNU_200727_EN-50-STRATEGIC INTELLECTUAL PROPERTY SOLUTIONS
# Seed Unique Values (Name): ['!DNU_200727_EN-50-Amazon', '!DNU_200727_EN-50-Datavizz', '!DNU_200727_EN-50-Deloitte Haskins Sells LLP', '!DNU_200727_EN-50-GRANT THORNTON INDIA LLP', '!DNU_200727_EN-50-KAMDHENU XEROX & STATIONERY', '!DNU_200727_EN-50-KANJ & CO. LLP', '!DNU_200727_EN-50-KPMG', '!DNU_200727_EN-50-Khushi Caterers', '!DNU_200727_EN-50-Legalogic Consulting', '!DNU_200727_EN-50-Maheshwari Foods & Hospitality (Pune) LLP', '!DNU_200727_EN-50-PGH EXPRESS KITCHEN LLP', '!DNU_200727_EN-50-Price Waterhouse Coopers LLP', '!DNU_200727_EN-50-RJ 12 TEA AND COFFEE SHOP', '!DNU_200727_EN-50-SAARVAM & ASSOCIATES', '!DNU_200727_EN-50-SAC & Co LLP', '!DNU_200727_EN-50-SHUBAN INTERNATIONAL', '!DNU_200727_EN-50-STRATEGIC INTELLECTUAL PROPERTY SOLUTIONS', '!DNU_200727_EN-50-Vipanan Analytical Technologies LLP', '!DNU_200727_EN-50-Walker Chandiok & Co LLP', 'Default Tax Agency IN', 'EN-50- Akshata   Baniya', 'EN-50- Ganesh    Pore', 'EN-50-121 Connects Private Limited', 'EN-50-9.9 GROUP PRIVATE LIMITED', 'EN-50-A2Z ONLINE SERVICES PVT LTD', 'EN-50-AARA VILLA', 'EN-50-AAYATI ECOVENTURES PRIVATE LIMITED', 'EN-50-AAYUSHI RAVI NARAYAN', 'EN-50-ABHINANDAN  SINGH', 'EN-50-ABP PVT LTD', 'EN-50-ACE DATA DEVICES PVT LTD', 'EN-50-ADFACTORS PR PRIVATE LIMITED', 'EN-50-ADITYA BIRLA HEALTH SERVICES PRIVATE LIMITED', 'EN-50-ADP INDIA PRIVATE LIMITED', 'EN-50-AFour Technologies Pvt.Ltd.', 'EN-50-AGARWAL HOSPITALITY PRIVATE LIMITED', 'EN-50-AJANTA TECHAGRO LAND DEVELOPMENT PRIVATE LTD', 'EN-50-AJIT ELECTRICALS', 'EN-50-ALIKE THOUGHTS SOLUTIONS', 'EN-50-ALLIED SERVICES', 'EN-50-ALLSEC TECHNOLOGIES LIMITED', 'EN-50-AMBIENCE HOTELS & RESORTS PRIVATE LIMITED', 'EN-50-AMIT DILIP SHINDORE', 'EN-50-AMPLE DIGITAL PRIVATE LIMITED', 'EN-50-AMPLE TECHNOLOGIES PRIVATE LIMITED', 'EN-50-AMRUT SOFTWARE PRIVATE LIMITED', 'EN-50-AMRUTA S ZENDE', 'EN-50-ANI  TECHNOL OGIES  PRIVATE  LIMITED (Ola Cabs)', 'EN-50-ANICHE INFOTECH SOLUTIONS PRIVATE LIMITED', 'EN-50-ANSEC HUMAN RESOURCE SERVICES LIMITED', 'EN-50-ANZY CAREERS PRIVATE LIMITED', 'EN-50-ARA RESOURCES PRIVATE LIMITED', 'EN-50-ARANYAGIRI COUNTRYSIDE RESORT', 'EN-50-ARYAN ENTERPRISES_Ajit Sharma', 'EN-50-ASTRA SYSTEMS', 'EN-50-ATLASSIAN Pty Ltd (Jira)', 'EN-50-AWFIS SPACE SOLUTIONS PRIVATE LIMITED', 'EN-50-AWLIV LIVING SOLUTIONS PRIVATE LIMITED', 'EN-50-AZURE RESTAURANTS PUNE PVT LTD', 'EN-50-Aayush H Shah', 'EN-50-Abhay  S Wagh', 'EN-50-Abhay K Shirale', 'EN-50-Abhishek P  More', 'EN-50-Accutech Power Solution Pvt Ltd', 'EN-50-Aditya  R Manapure', 'EN-50-Aditya S Vaidya', 'EN-50-Adorit IT Services Pvt Ltd', 'EN-50-Advait M  Thakur', 'EN-50-Adventure Mantra Pvt Ltd', 'EN-50-Aegon Life Insurance Company Limited', 'EN-50-Akash Mishra', 'EN-50-Alliance Pro IT Pvt Ltd', 'EN-50-Amazon', 'EN-50-American Express INR (Amex) ( Card No 3765 35363731002', 'EN-50-Amisha M Pawar', 'EN-50-Amit Enterprises', 'EN-50-Amruta Patwardhan', 'EN-50-Anantta Hospitality', 'EN-50-Aniket S Kankekar', 'EN-50-Anjali Babasaheb Gaikwad', 'EN-50-Anvay Enterprises', 'EN-50-Aon Consulting, Inc. (NJ)', 'EN-50-Apple South Asia Pte Ltd', 'EN-50-Apurva A Khamkar', 'EN-50-Asawari  S Sayagaon', 'EN-50-Ashapura Agency', 'EN-50-Ashish Deepak Karkare', 'EN-50-Asma Tamboli', 'EN-50-Aspose Pty Ltd', 'EN-50-Assure Hrlabs India Pvt Ltd', 'EN-50-BALAJI STATIONERY & SUPPLIER', 'EN-50-BAMBOO AND BRICKS RESORT', 'EN-50-BC EDUCATION INDIA PRIVATE LIMITED', 'EN-50-BENIR E STORE SOLUTION', 'EN-50-BENISON TECHNOLOGIES PRIVATE LIMITED', 'EN-50-BENNETT COLEMAN & CO LTD', 'EN-50-BHANDARMATH MEDIA WORKS (RJ Prabhu)', 'EN-50-BITS PILANI K K BIRLA GOA CHAMPUS', 'EN-50-BLOB INFOTECH PRIVATE LIMITED', 'EN-50-BOUGAINVILLEA RESORT', 'EN-50-BOX Inc', 'EN-50-BRAHMADNYA FOODS', 'EN-50-BRAMHACORP LIMITED', 'EN-50-BRIO TECHNOLOGIES PRIVATE LIMITED', 'EN-50-BROWSERSTACK.COM', 'EN-50-Balaji  Janakiraman', 'EN-50-Bharti Airtel Ltd', 'EN-50-Bhavik  G Ransubhe', 'EN-50-Bistro Hospitality Pvt Ltd', 'EN-50-Blue Leaf Corporate Solutions P Ltd', 'EN-50-Bluebell Telesystem and Services', 'EN-50- ...
# Common Values: []
# Input Unique Count: 913, Common Count: 0, Ratio: 0.00
# Mapping Rejected based on Common Elements Ratio.
#
#
# Mapping Attempt: 'druva_seed:Name' -> 'Amount (Base Currency) w/ Correct GL Sign'
# Input Unique Values (Amount (Base Currency) w/ Correct GL Sign): ['-0.01', '-0.1', '-0.11', '-0.2', '-0.25', '-0.28', '-0.3', '-0.4', '-0.44', '-0.58', '-1.16', '-100.0', '-100.63', '-1000.0', '-1030.0', '-103635.0', '-106.78', '-1060.0', '-1114.0', '-11250.0', '-11252.0', '-115.0', '-11516.0', '-118.3', '-1180.0', '-119.0', '-12.0', '-120.0', '-1200.0', '-120000.0', '-121.0', '-121.04', '-1240.0', '-125.0', '-126.0', '-12600.0', '-1277.0', '-128.0', '-129.05', '-129.6', '-130.0', '-13084.0', '-1312.5', '-1322.0', '-1329.31', '-1351.2', '-1375.2', '-137600.0', '-1395.0', '-14.0', '-141.0', '-1413.06', '-1415004.0', '-142.0', '-143.5', '-144.0', '-14437.0', '-1450.0', '-147.75', '-14764.81', '-150.56', '-15000.0', '-1512.0', '-152.0', '-155.0', '-1550.0', '-156.0', '-156.4', '-156.6', '-157.0', '-158.0', '-159.0', '-16.0', '-162.05', '-1620.0', '-1630.0', '-164.0', '-165.0', '-1652.14', '-1660.0', '-168.0', '-1716.0', '-17360.0', '-1740.0', '-175.0', '-175.48', '-17528.0', '-1776.0', '-180.0', '-183.0', '-1832.0', '-18324.0', '-1850.0', '-19.0', '-19.43', '-1920.0', '-193.5', '-193.75', '-19471.0', '-195.0', '-1981.0', '-2.0', '-2000.0', '-20021.13', '-203.75', '-205.0', '-2060.0', '-
# Seed Unique Values (Name): ['!DNU_200727_EN-50-Amazon', '!DNU_200727_EN-50-Datavizz', '!DNU_200727_EN-50-Deloitte Haskins Sells LLP', '!DNU_200727_EN-50-GRANT THORNTON INDIA LLP', '!DNU_200727_EN-50-KAMDHENU XEROX & STATIONERY', '!DNU_200727_EN-50-KANJ & CO. LLP', '!DNU_200727_EN-50-KPMG', '!DNU_200727_EN-50-Khushi Caterers', '!DNU_200727_EN-50-Legalogic Consulting', '!DNU_200727_EN-50-Maheshwari Foods & Hospitality (Pune) LLP', '!DNU_200727_EN-50-PGH EXPRESS KITCHEN LLP', '!DNU_200727_EN-50-Price Waterhouse Coopers LLP', '!DNU_200727_EN-50-RJ 12 TEA AND COFFEE SHOP', '!DNU_200727_EN-50-SAARVAM & ASSOCIATES', '!DNU_200727_EN-50-SAC & Co LLP', '!DNU_200727_EN-50-SHUBAN INTERNATIONAL', '!DNU_200727_EN-50-STRATEGIC INTELLECTUAL PROPERTY SOLUTIONS', '!DNU_200727_EN-50-Vipanan Analytical Technologies LLP', '!DNU_200727_EN-50-Walker Chandiok & Co LLP', 'Default Tax Agency IN', 'EN-50- Akshata   Baniya', 'EN-50- Ganesh    Pore', 'EN-50-121 Connects Private Limited', 'EN-50-9.9 GROUP PRIVATE LIMITED', 'EN-50-A2Z ONLINE SERVICES PVT LTD', 'EN-50-AARA VILLA', 'EN-50-AAYATI ECOVENTURES PRIVATE LIMITED', 'EN-50-AAYUSHI RAVI NARAYAN', 'EN-50-ABHINANDAN  SINGH', 'EN-50-ABP PVT LTD', 'EN-50-ACE DATA DEVICES PVT LTD', 'EN-50-ADFACTORS PR PRIVATE LIMITED', 'EN-50-ADITYA BIRLA HEALTH SERVICES PRIVATE LIMITED', 'EN-50-ADP INDIA PRIVATE LIMITED', 'EN-50-AFour Technologies Pvt.Ltd.', 'EN-50-AGARWAL HOSPITALITY PRIVATE LIMITED', 'EN-50-AJANTA TECHAGRO LAND DEVELOPMENT PRIVATE LTD', 'EN-50-AJIT ELECTRICALS', 'EN-50-ALIKE THOUGHTS SOLUTIONS', 'EN-50-ALLIED SERVICES', 'EN-50-ALLSEC TECHNOLOGIES LIMITED', 'EN-50-AMBIENCE HOTELS & RESORTS PRIVATE LIMITED', 'EN-50-AMIT DILIP SHINDORE', 'EN-50-AMPLE DIGITAL PRIVATE LIMITED', 'EN-50-AMPLE TECHNOLOGIES PRIVATE LIMITED', 'EN-50-AMRUT SOFTWARE PRIVATE LIMITED', 'EN-50-AMRUTA S ZENDE', 'EN-50-ANI  TECHNOL OGIES  PRIVATE  LIMITED (Ola Cabs)', 'EN-50-ANICHE INFOTECH SOLUTIONS PRIVATE LIMITED', 'EN-50-ANSEC HUMAN RESOURCE SERVICES LIMITED', 'EN-50-ANZY CAREERS PRIVATE LIMITED', 'EN-50-ARA RESOURCES PRIVATE LIMITED', 'EN-50-ARANYAGIRI COUNTRYSIDE RESORT', 'EN-50-ARYAN ENTERPRISES_Ajit Sharma', 'EN-50-ASTRA SYSTEMS', 'EN-50-ATLASSIAN Pty Ltd (Jira)', 'EN-50-AWFIS SPACE SOLUTIONS PRIVATE LIMITED', 'EN-50-AWLIV LIVING SOLUTIONS PRIVATE LIMITED', 'EN-50-AZURE RESTAURANTS PUNE PVT LTD', 'EN-50-Aayush H Shah', 'EN-50-Abhay  S Wagh', 'EN-50-Abhay K Shirale', 'EN-50-Abhishek P  More', 'EN-50-Accutech Power Solution Pvt Ltd', 'EN-50-Aditya  R Manapure', 'EN-50-Aditya S Vaidya', 'EN-50-Adorit IT Services Pvt Ltd', 'EN-50-Advait M  Thakur', 'EN-50-Adventure Mantra Pvt Ltd', 'EN-50-Aegon Life Insurance Company Limited', 'EN-50-Akash Mishra', 'EN-50-Alliance Pro IT Pvt Ltd', 'EN-50-Amazon', 'EN-50-American Express INR (Amex) ( Card No 3765 35363731002', 'EN-50-Amisha M Pawar', 'EN-50-Amit Enterprises', 'EN-50-Amruta Patwardhan', 'EN-50-Anantta Hospitality', 'EN-50-Aniket S Kankekar', 'EN-50-Anjali Babasaheb Gaikwad', 'EN-50-Anvay Enterprises', 'EN-50-Aon Consulting, Inc. (NJ)', 'EN-50-Apple South Asia Pte Ltd', 'EN-50-Apurva A Khamkar', 'EN-50-Asawari  S Sayagaon', 'EN-50-Ashapura Agency', 'EN-50-Ashish Deepak Karkare', 'EN-50-Asma Tamboli', 'EN-50-Aspose Pty Ltd', 'EN-50-Assure Hrlabs India Pvt Ltd', 'EN-50-BALAJI STATIONERY & SUPPLIER', 'EN-50-BAMBOO AND BRICKS RESORT', 'EN-50-BC EDUCATION INDIA PRIVATE LIMITED', 'EN-50-BENIR E STORE SOLUTION', 'EN-50-BENISON TECHNOLOGIES PRIVATE LIMITED', 'EN-50-BENNETT COLEMAN & CO LTD', 'EN-50-BHANDARMATH MEDIA WORKS (RJ Prabhu)', 'EN-50-BITS PILANI K K BIRLA GOA CHAMPUS', 'EN-50-BLOB INFOTECH PRIVATE LIMITED', 'EN-50-BOUGAINVILLEA RESORT', 'EN-50-BOX Inc', 'EN-50-BRAHMADNYA FOODS', 'EN-50-BRAMHACORP LIMITED', 'EN-50-BRIO TECHNOLOGIES PRIVATE LIMITED', 'EN-50-BROWSERSTACK.COM', 'EN-50-Balaji  Janakiraman', 'EN-50-Bharti Airtel Ltd', 'EN-50-Bhavik  G Ransubhe', 'EN-50-Bistro Hospitality Pvt Ltd', 'EN-50-Blue Leaf Corporate Solutions P Ltd', 'EN-50-Bluebell Telesystem and Services', 'EN-50- ...
# Common Values: []
# Input Unique Count: 913, Common Count: 0, Ratio: 0.00
# Mapping Rejected based on Common Elements Ratio.
#
#
# === Final Verified Mappings ===
# Seed File 'druva_seed': Seed Column 'Name' -> Input Column 'Vendor' (Ratio: 0.89)
